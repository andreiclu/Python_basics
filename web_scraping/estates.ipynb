# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000")
c = r.content

soup = BeautifulSoup(c, "html.parser")

all = soup.find_all("div",{"class":"offer-item-details"})


all[0].find("li",{"class":"offer-item-price"}).text.replace("\n","").replace(" ","")

last_page = soup.find("ul", {"class": "pager"})
li = soup.find('ul', class_='pager')
pages = [a.text for a in li.find_all('li')]
l_page = pages[-2]
print (l_page)
# Out:
# 37

# %%
l = []
base_url = "https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page="
for page in range(1, int(l_page+1)):
    print(base_url+str(page))
    r=requests.get(base_url+str(page))
    c=r.content
    soup=BeautifulSoup(c, "html.parser")
    all = soup.find_all("div",{"class":"offer-item-details"})
    for item in all:
        d = {}
        d["Price"] = item.find("li",{"class":"offer-item-price"}).text.replace("\n","").replace(" ","")
        d["Description"] = item.find_all("span",{"class", "offer-item-title"})[0].text
        d["Rooms"] = item.find("li",{"class", "offer-item-rooms hidden-xs"}).text
        try:
            d["Build Area"] = item.find_all("li", {"class", "hidden-xs offer-item-area"})[0].text
        except:
            d["Build Area"] = None
        try: 
            d["Land Area"] = item.find_all("li", {"class", "hidden-xs offer-item-area"})[1].text
        except:
            d["Land Area"] = None
        for column_group in item.find_all("p", {"class": "text-nowrap"}):
            d["Location"] = (column_group.text)

        l.append(d)
# Out:
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=1
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=2
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=3
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=4
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=5
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=6
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=7
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=8
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=9
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=10
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=11
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=12
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=13
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=14
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=15
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=16
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=17
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=18
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=19
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=20
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=21
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=22
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=23
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=24
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=25
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=26
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=27
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=28
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=29
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=30
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=31
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=32
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=33
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=34
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=35
# https://www.storia.ro/vanzare/casa/iasi/iasi/?search%5Bfilter_float_price%3Ato%5D=150000&search%5Border%5D=created_at_first%3Adesc&page=36

# %%
import pandas
df = pandas.DataFrame(l)
df
# Out:
#        Price                                        Description     Rooms  \
# 0     90000€  Casa tip duplex,3 camere,in zona centrala,mobi...  3 camere
# 1    115000€  ESQ Village 3, cel mai mare ansamblu de case d...  4 camere
# 2    139000€  Casa individuala CUG - Horpaz, 170 mp utili,62...  8 camere
# 3    130000€  Casa individuala , 144 mp , Beci , 130000 Nego...  4 camere
# 4      9500€  Casa, garaje auto si containere din panou sand...  3 camere
# ..       ...                                                ...       ...
# 967   95000€  D+P+1+M! Vila 4 camere, 130 mp utili, Valea Ad...  4 camere
# 968   74500€  Casa individuala, 3 camere, 400 mp teren, Vale...  3 camere
# 969  128000€  Vila 5 camere, 123 mp utili, Valea Adanca - Mi...  5 camere
# 970   95000€             Casa 4 camere, 120 mp utili, Miroslava  4 camere
# 971   95000€  D+P+1+M! Vila 4 camere, 130 mp utili, Valea Ad...  4 camere
#
#     Build Area     Land Area                                 Location
# 0        72 m²  teren 110 m²  Casa de vanzare: Iasi (judet), Pacurari
# 1       125 m²  teren 140 m²      Casa de vanzare: Iasi (judet), Iasi
# 2       235 m²  teren 620 m²       Casa de vanzare: Iasi (judet), CUG
# 3       144 m²  teren 520 m²    Casa de vanzare: Iasi (judet), Bucium
# 4        80 m²   teren 80 m²      Casa de vanzare: Iasi (judet), Iasi
# ..         ...           ...                                      ...
# 967     160 m²  teren 225 m²      Casa de vanzare: Iasi (judet), Iasi
# 968      95 m²  teren 400 m²      Casa de vanzare: Iasi (judet), Iasi
# 969     150 m²  teren 450 m²      Casa de vanzare: Iasi (judet), Iasi
# 970     150 m²  teren 385 m²      Casa de vanzare: Iasi (judet), Iasi
# 971     160 m²  teren 225 m²      Casa de vanzare: Iasi (judet), Iasi
#
# [972 rows x 6 columns]
